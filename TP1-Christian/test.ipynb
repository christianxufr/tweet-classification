# %%
from utils.data_loader import DataLoader
from text_to_vec import TextToVec
from sklearn.model_selection import train_test_split
from utils.visualize import Visualize
from tensorflow.keras.utils import to_categorical
from utils.saving import Saving
from preprocess import Preprocess
import numpy as np
import pandas as pd
from models import *

from utils.data_loader import DataLoader
data_loader = DataLoader("../data")

# %%
data = data_loader.load_tweet_v2(data_loader.train_7_v2_path)\
    .append(data_loader.load_tweet_v2(data_loader.val_7_v2_path))\
    .append(data_loader.load_tweet(data_loader.train_3_path))\
    .append(data_loader.load_tweet(data_loader.train_7_path))

# %%
data_loader = DataLoader("../data")  # "/home/epita/cardamin/drive-reader/result")
saving = Saving(directory="results")
preprocess = Preprocess(data_loader)
text2vec = TextToVec.load("save/tp-all-300.save")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/christian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/christian/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
test_3 = data_loader.load_tweet(data_loader.test_3_path)
test_7 = data_loader.load_tweet_v2(data_loader.val_7_v2_path)

texts = test_3["text"].values
texts = np.vectorize(preprocess.text_standardization)(texts)
texts = text2vec.sequence_texts(texts)

model = saving.load_model("blstm_3")
label = to_categorical(test_3["class"], model.output_shape[-1])
# Out:
# [Saving] Loading model at: results/blstm_3/blstm_3.h5

# %%
np.argmax(model.predict(texts), axis=1) - 1
# Out:
# array([-1,  0, -1, ..., -1, -1, -1])

# %%
test_3["predict"] = np.argmax(model.predict(texts), axis=1) - 1


score, acc = model.evaluate(texts, label)
print('Test score:', score)
print('Test accuracy:', acc)
data_loader.write_tweet_v2(test_3, "/tmp/predict.csv")
# Out:
# 1020/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Test score: 0.7934064138169382
# Test accuracy: 0.6166667

# %%
model, model_name = model3_lstm(text2vec.get_embedding_layer(False), saving)
texts = data["text"].values
texts = np.vectorize(preprocess.text_standardization)(texts)
texts = text2vec.sequence_texts(texts)

# %%
texts.shape
# Out:
# (53593, 32)

# %%
nt = data["text"][:2]
pre = np.vectorize(preprocess.text_standardization)(nt)
output = text2vec.sequence_texts(pre)

# %%
tp:TextProcessing = TextProcessing.load("tp-all-300.save")

tp.sequence_texts(vocab)

# %%
from utils.saving import Saving
from keras.layers import Dense, Dropout
from keras.models import Sequential, load_model
saving = Saving(directory="results")

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=10))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['acc'])


model.summary()
model.save("model.h5")
model2 = load_model("model.h5")
model2.pop()
model2.summary()
